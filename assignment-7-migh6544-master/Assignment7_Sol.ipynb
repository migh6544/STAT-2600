# %% [markdown]
# # Assignment 7 (10 Points): Numpy

# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()  # set plot style

# %%
# !head -4 data/diamonds.csv
# Out:
# carat,cut,color,clarity,depth,table,price,x,y,z
# 0.23,Ideal,E,SI2,61.5,55,326,3.95,3.98,2.43
# 0.21,Premium,E,SI1,59.8,61,326,3.89,3.84,2.31
# 0.23,Good,E,VS1,56.9,65,327,4.05,4.07,2.31

# %%
diamonds = pd.read_csv('data/diamonds.csv')
prices = np.array(diamonds['price'])
carats = np.array(diamonds['carat'])

# %% [markdown]
# ### Q1 (2 points): Print the mean, standard deviation, minimum, maximum, 25th percentile, median, and 75th percentile of the prices array.

# %%
print('========================================')
print('Mean price:         ', np.mean(prices))
print('Standard deviation: ', np.std(prices))
print('Minimum price:      ', np.min(prices))
print('Maximum price:      ', np.max(prices))
print('========================================')
print('25th percentile:    ', np.percentile(prices, 25))
print('Median:             ', np.percentile(prices, 50))
print('75th percentile:    ', np.percentile(prices, 75))
print('========================================')
# Out:
# ...
# Mean price:          3932.799721913237
# Standard deviation:  3989.4027576288736
# Minimum price:       326
# Maximum price:       18823
# ...
# 25th percentile:     950.0
# Median:              2401.0
# 75th percentile:     5324.25
# ...

# %% [markdown]
# ### Q2 (2 points): Plot the histogram of the prices array.

# %%
plt.hist(prices) 
plt.title("Price Distribution")
plt.ylabel('number')
plt.xlabel('price')
plt.show()

# %% [markdown]
# ### Q3 (2 points): Reproduce the following output.

# %%
print('Number of diamonds with price bigger than 1800:         ', np.sum(prices > 1800))
print('Average carat for diamonds with price bigger than 1800: ', diamonds.loc[diamonds['price'] > 1800]['carat'].mean())
# Out:
# Number of diamonds with price bigger than 1800:          31421
# Average carat for diamonds with price bigger than 1800:  1.0920012093822602

# %% [markdown]
# ### Q4 (4 points): Reproduce the following scatter plot. The red circles represent a random subsample of the data.

# %%
indices = np.random.choice(prices.shape[0], 20, replace=False)
P_random = prices[indices]
C_random = carats[indices]
plt.scatter(np.log2(prices), np.log2(carats), alpha = .3)
plt.scatter(np.log2(P_random), np.log2(C_random),
            facecolor='none', s=200, edgecolors='r')
plt.xlabel('log2(prices)')
plt.ylabel('log2(carats)');
